# %% [markdown]
# ## Convert objects values to numeric values
#
# In order to use a classification algorithm the dataset values have to be confirmed to numeric values.
#
# The following steps will be to convert the dataset object values to numeric values:
#
# - 1 Identify all datatypes in the dataset
# - 2 Convert non-categorical feature values to numeric
# - 3 Convert categorical feature values to numeric

# %% [markdown]
# ### 1 Identify all data types in the dataset

# %%
#check data types for each feature

combined.dtypes
# Out:
# AltitudeVariation             object
# VehicleSpeedInstantaneous     object
# VehicleSpeedAverage           object
# VehicleSpeedVariance          object
# VehicleSpeedVariation         object
# LongitudinalAcceleration      object
# EngineLoad                    object
# EngineCoolantTemperature     float64
# ManifoldAbsolutePressure     float64
# EngineRPM                     object
# MassAirFlow                   object
# IntakeAirTemperature         float64
# VerticalAcceleration          object
# FuelConsumptionAverage        object
# drivingStyle                  object
# Car                           object
# Journey                        int64
# dtype: object

# %%
#The EngineRPM column numeric data has commas instead of decimal points. So will have to replace comma with decimal prior to converting 
#to float

combined.tail()
# Out:
#       AltitudeVariation VehicleSpeedInstantaneous VehicleSpeedAverage  \
# 23765                 1               28.79999924         28.55999908
# 23766       1.699996948               30.59999847          28.5299991
# 23767       1.800003052               29.69999886         28.49999908
# 23768       2.100006104               29.69999886         28.40999908
# 23769               1.5               33.29999924         28.34999911
#
#       VehicleSpeedVariance VehicleSpeedVariation LongitudinalAcceleration  \
# 23765          57.19057079           3.600000381                  -0.0292
# 23766          57.01026584           1.799999237                  -0.0304
# 23767           56.8830454          -0.899999619                  -0.1684
# 23768          56.16090993                     0                  -0.0644
# 23769          55.34084256           3.600000381                  -0.1817
#
#         EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  \
# 23765  25.88235283                      81.0                     115.0
# 23766  11.76470566                      81.0                     106.0
# 23767  98.03921509                      81.0                     106.0
# 23768  79.60784149                      80.0                     112.0
# 23769           80                      80.0                     113.0
#
#       EngineRPM  MassAirFlow  IntakeAirTemperature VerticalAcceleration  \
# 23765    1755,5  20.46999931                  25.0              -0.1661
# 23766     736,5  17.73999977                  25.0              -0.1987
# 23767      1254  9.520000458                  24.0              -0.1156
# 23768      1254  14.90999985                  23.0               -0.076
# 23769    1363,5  15.32999992                  23.0              -0.0605
#
#       FuelConsumptionAverage   drivingStyle      Car  Journey
# 23765            14.57800293  EvenPaceStyle  peugeot        4
# 23766            14.58564186  EvenPaceStyle  peugeot        4
# 23767            14.54729366  EvenPaceStyle  peugeot        4
# 23768            14.54682827  EvenPaceStyle  peugeot        4
# 23769            14.55406761  EvenPaceStyle  peugeot        4

# %%
#changing EngineRPM comma separator to decimal separator

combined['EngineRPM'] = combined['EngineRPM'].astype(str)
combined['EngineRPM'] = combined['EngineRPM'].str.replace(',', '.')

# %%
#check that EngineRPM is now showing decimal separators

combined.tail()
# Out:
#       AltitudeVariation VehicleSpeedInstantaneous VehicleSpeedAverage  \
# 23765                 1               28.79999924         28.55999908
# 23766       1.699996948               30.59999847          28.5299991
# 23767       1.800003052               29.69999886         28.49999908
# 23768       2.100006104               29.69999886         28.40999908
# 23769               1.5               33.29999924         28.34999911
#
#       VehicleSpeedVariance VehicleSpeedVariation LongitudinalAcceleration  \
# 23765          57.19057079           3.600000381                  -0.0292
# 23766          57.01026584           1.799999237                  -0.0304
# 23767           56.8830454          -0.899999619                  -0.1684
# 23768          56.16090993                     0                  -0.0644
# 23769          55.34084256           3.600000381                  -0.1817
#
#         EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  \
# 23765  25.88235283                      81.0                     115.0
# 23766  11.76470566                      81.0                     106.0
# 23767  98.03921509                      81.0                     106.0
# 23768  79.60784149                      80.0                     112.0
# 23769           80                      80.0                     113.0
#
#       EngineRPM  MassAirFlow  IntakeAirTemperature VerticalAcceleration  \
# 23765    1755.5  20.46999931                  25.0              -0.1661
# 23766     736.5  17.73999977                  25.0              -0.1987
# 23767      1254  9.520000458                  24.0              -0.1156
# 23768      1254  14.90999985                  23.0               -0.076
# 23769    1363.5  15.32999992                  23.0              -0.0605
#
#       FuelConsumptionAverage   drivingStyle      Car  Journey
# 23765            14.57800293  EvenPaceStyle  peugeot        4
# 23766            14.58564186  EvenPaceStyle  peugeot        4
# 23767            14.54729366  EvenPaceStyle  peugeot        4
# 23768            14.54682827  EvenPaceStyle  peugeot        4
# 23769            14.55406761  EvenPaceStyle  peugeot        4

# %% [markdown]
# ### 2 Convert non-categorical feature values to numeric

# %%
#create a new dataset labelled numeric to indicate the change in data type

new_numeric_dataset = combined

new_numeric_dataset
# Out:
#       AltitudeVariation VehicleSpeedInstantaneous VehicleSpeedAverage  \
# 0            -2.2999878               25.67051888         13.22350089
# 1            -2.0999756               24.09425926         13.63891915
# 2                  -1.5               22.74317932         14.03104293
# 3             0.1000366               22.29281998         14.17107305
# 4             0.0999756               23.64389992          14.3289535
# ...                 ...                       ...                 ...
# 23765                 1               28.79999924         28.55999908
# 23766       1.699996948               30.59999847          28.5299991
# 23767       1.800003052               29.69999886         28.49999908
# 23768       2.100006104               29.69999886         28.40999908
# 23769               1.5               33.29999924         28.34999911
#
#       VehicleSpeedVariance VehicleSpeedVariation LongitudinalAcceleration  \
# 0              121.5926897            -2.4769802                   0.3555
# 1              120.4225707           -1.57625962                   0.4492
# 2              118.4567689           -1.35107994                   0.4258
# 3              117.5713084           -0.45035934                    0.414
# 4              117.0741485            1.35107994                   0.3945
# ...                    ...                   ...                      ...
# 23765          57.19057079           3.600000381                  -0.0292
# 23766          57.01026584           1.799999237                  -0.0304
# 23767           56.8830454          -0.899999619                  -0.1684
# 23768          56.16090993                     0                  -0.0644
# 23769          55.34084256           3.600000381                  -0.1817
#
#         EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  \
# 0      4.705882549                      68.0                     106.0
# 1      10.58823586                      68.0                     103.0
# 2      27.45098114                      68.0                     103.0
# 3      24.31372643                      69.0                     104.0
# 4               20                      69.0                     104.0
# ...            ...                       ...                       ...
# 23765  25.88235283                      81.0                     115.0
# 23766  11.76470566                      81.0                     106.0
# 23767  98.03921509                      81.0                     106.0
# 23768  79.60784149                      80.0                     112.0
# 23769           80                      80.0                     113.0
#
#       EngineRPM  MassAirFlow  IntakeAirTemperature VerticalAcceleration  \
# 0          1796  15.81000042                  24.0              -0.1133
# 1          1689  14.64999962                  22.0              -0.1289
# 2          1599  11.85000038                  21.0              -0.1328
# 3          1620  12.21000004                  20.0              -0.0859
# 4          1708  11.90999985                  21.0              -0.0664
# ...         ...          ...                   ...                  ...
# 23765    1755.5  20.46999931                  25.0              -0.1661
# 23766     736.5  17.73999977                  25.0              -0.1987
# 23767      1254  9.520000458                  24.0              -0.1156
# 23768      1254  14.90999985                  23.0               -0.076
# 23769    1363.5  15.32999992                  23.0              -0.0605
#
#       FuelConsumptionAverage   drivingStyle      Car  Journey
# 0                19.49733543  EvenPaceStyle     opel        1
# 1                19.51572227  EvenPaceStyle     opel        1
# 2                19.44176483  EvenPaceStyle     opel        1
# 3                19.38876915  EvenPaceStyle     opel        1
# 4                19.30163765  EvenPaceStyle     opel        1
# ...                      ...            ...      ...      ...
# 23765            14.57800293  EvenPaceStyle  peugeot        4
# 23766            14.58564186  EvenPaceStyle  peugeot        4
# 23767            14.54729366  EvenPaceStyle  peugeot        4
# 23768            14.54682827  EvenPaceStyle  peugeot        4
# 23769            14.55406761  EvenPaceStyle  peugeot        4
#
# [23770 rows x 17 columns]

# %%
#validate data types 

new_numeric_dataset.dtypes
# Out:
# AltitudeVariation             object
# VehicleSpeedInstantaneous     object
# VehicleSpeedAverage           object
# VehicleSpeedVariance          object
# VehicleSpeedVariation         object
# LongitudinalAcceleration      object
# EngineLoad                    object
# EngineCoolantTemperature     float64
# ManifoldAbsolutePressure     float64
# EngineRPM                     object
# MassAirFlow                   object
# IntakeAirTemperature         float64
# VerticalAcceleration          object
# FuelConsumptionAverage        object
# drivingStyle                  object
# Car                           object
# Journey                        int64
# dtype: object

# %%
#convert numeric object columns to float or integer Note: having issues converting EngineRPM (it creates new NaNs), so will
#do it separately

columns_to_convert = ['AltitudeVariation', 'VehicleSpeedInstantaneous', 'VehicleSpeedAverage','VehicleSpeedVariance','VehicleSpeedVariation','LongitudinalAcceleration','EngineLoad','MassAirFlow','VerticalAcceleration','FuelConsumptionAverage' ]

for col in columns_to_convert:
    new_numeric_dataset[col] = pd.to_numeric(new_numeric_dataset[col], errors='coerce')

# %%
#check non-categorical datatypes after convert process 

new_numeric_dataset.dtypes
# Out:
# AltitudeVariation            float64
# VehicleSpeedInstantaneous    float64
# VehicleSpeedAverage          float64
# VehicleSpeedVariance         float64
# VehicleSpeedVariation        float64
# LongitudinalAcceleration     float64
# EngineLoad                   float64
# EngineCoolantTemperature     float64
# ManifoldAbsolutePressure     float64
# EngineRPM                     object
# MassAirFlow                  float64
# IntakeAirTemperature         float64
# VerticalAcceleration         float64
# FuelConsumptionAverage       float64
# drivingStyle                  object
# Car                           object
# Journey                        int64
# dtype: object

# %%
#convert EngineRPM into numeric data type

new_numeric_dataset['EngineRPM'] = pd.to_numeric(new_numeric_dataset['EngineRPM'])

# %%
#Validate all non-categorical data types are now numeric after change to EngineRPM

new_numeric_dataset.dtypes
# Out:
# AltitudeVariation            float64
# VehicleSpeedInstantaneous    float64
# VehicleSpeedAverage          float64
# VehicleSpeedVariance         float64
# VehicleSpeedVariation        float64
# LongitudinalAcceleration     float64
# EngineLoad                   float64
# EngineCoolantTemperature     float64
# ManifoldAbsolutePressure     float64
# EngineRPM                    float64
# MassAirFlow                  float64
# IntakeAirTemperature         float64
# VerticalAcceleration         float64
# FuelConsumptionAverage       float64
# drivingStyle                  object
# Car                           object
# Journey                        int64
# dtype: object

# %% [markdown]
# ### 3 Convert categorical feature values to numeric

# %%
#convert the drivingStyle & car features to numeric values

combined['drivingStyle'] = pd.Categorical(combined['drivingStyle']).codes
combined['Car'] = pd.Categorical(combined['Car']).codes

# %%
#Validate all data types are now numeric

new_numeric_dataset.dtypes
# Out:
# AltitudeVariation            float64
# VehicleSpeedInstantaneous    float64
# VehicleSpeedAverage          float64
# VehicleSpeedVariance         float64
# VehicleSpeedVariation        float64
# LongitudinalAcceleration     float64
# EngineLoad                   float64
# EngineCoolantTemperature     float64
# ManifoldAbsolutePressure     float64
# EngineRPM                    float64
# MassAirFlow                  float64
# IntakeAirTemperature         float64
# VerticalAcceleration         float64
# FuelConsumptionAverage       float64
# drivingStyle                    int8
# Car                             int8
# Journey                        int64
# dtype: object
